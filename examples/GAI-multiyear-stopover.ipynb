# %% [markdown]
# # GAI multiyear stopover model

# %% [markdown]
# ## Install the ButterflyLifespan package

# %%
library(remotes)
remotes::install_github("grosed/ButterflyLifespan/R-package")
# Out:
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo grosed/ButterflyLifespan@HEAD
# rlang (1.2.0     -> 1.3.0) [CRAN]
# Rcpp  (1.1.1-1.1 -> 1.1.2) [CRAN]
# Installing 2 packages: rlang, Rcpp
#
# Installing packages into ‘/home/grosed/support/rachael/R-packages’
# (as ‘lib’ is unspecified)
# ── R CMD build ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/tmp/RtmpbVKXG5/remotes3d4b5253e1e60/grosed-ButterflyLifespan-946d816/R-package/DESCRIPTION’
# ─  preparing ‘ButterflyLifespan’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘ButterflyLifespan_1.2.0.tar.gz’
# Installing package into ‘/home/grosed/support/rachael/R-packages’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ## Load the library

# %%
library(ButterflyLifespan)
# Out:
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: reshape2

# %% [markdown]
# ## Lazy load the data

# %%
data(dark_green_fritillary_weekly)
dgf_week <- dark_green_fritillary_weekly

# %% [markdown]
# ## For demonstration purposes, take a random subset of the data

# %%
set.seed(12)
dgf_week <- dgf_week %>%  filter(YEAR > 2008) %>% filter(SITENO%in%sample(unique(dgf_week$SITENO),30))

# %% [markdown]
# ## Analyse data

# %%
output <- analysis_multiyear(dgf_week,"weekly","slope")
# Out:
# iter   10 value 1352.602675
# iter   20 value 1296.305095
# iter   30 value 1287.970496
# iter   40 value 1287.321797
# iter   50 value 1286.893947
# iter   60 value 1286.763058
# iter   70 value 1286.739451
# iter   80 value 1286.736386
# iter   90 value 1286.734822
# iter  100 value 1286.734494
# iter  110 value 1286.734438
# iter  120 value 1286.734433
# iter  130 value 1286.734433
# final  value 1286.734433
# converged
# final  value 1286.734433
# converged
# iter   10 value 1358.698875
# iter   20 value 1301.607130
# iter   30 value 1288.064010
# iter   40 value 1287.077088
# iter   50 value 1286.762911
# iter   60 value 1286.737332
# iter   70 value 1286.734989
# iter   80 value 1286.734586
# iter   90 value 1286.734442
# iter  100 value 1286.734433
# final  value 1286.734433
# converged
# final  value 1286.734433
# converged
# iter   10 value 1382.320464
# iter   20 value 1302.795709
# iter   30 value 1290.296817
# iter   40 value 1287.964625
# iter   50 value 1286.926828
# iter   60 value 1286.752167
# iter   70 value 1286.735583
# iter   80 value 1286.734864
# iter   90 value 1286.734542
# iter  100 value 1286.734454
# iter  110 value 1286.734438
# iter  120 value 1286.734434
# final  value 1286.734433
# converged
# final  value 1286.734433
# stopped after 0 iterations

# %%
lifespan <- output[[1]][["lifespan"]]

# %%
lifespan
# Out:
#    lifespan  ci_low    ci_up     year
# 1   7.041371  6.656649  7.426093 2009
# 2   7.359494  6.999003  7.719985 2010
# 3   7.700282  7.368504  8.032059 2011
# 4   8.065563  7.766151  8.364975 2012
# 5   8.457319  8.191539  8.723099 2013
# 6   8.877692  8.641138  9.114246 2014
# 7   9.329002  9.105955  9.552050 2015
# 8   9.813761  9.573377 10.054144 2016
# 9  10.334682 10.038145 10.631220 2017
# 10 10.894705 10.506383 11.283028 2018
